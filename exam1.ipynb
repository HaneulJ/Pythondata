# %%
stname = "유니코"; stage=20; stavg=95.869
print(stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다")
print(stname, "학생은 나이가 ", stage, "이고 평균은 ", stavg, "입니다", sep="")
print("%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg))
print("{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg))
print(f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다")

# %%
v1 = stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다"
v2 = "%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg)
v3 = "{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg)
v4 = f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다"
print(v1)
print(v2)
print(v3)
print(v4)

# %%
import sys
print(sys.version)

# %%
import os
print(os.getcwd())

# %%
# !jupyter kernelspec list

# %%
# !dir

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print(res.version)
print(res.msg)
res_header = res.getheaders()
print("[ header 정보 ]----------")
for s in res_header :
    print(s)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# OK
# [ header 정보 ]----------
# ('Server', 'NWS')
# ('Date', 'Tue, 30 Mar 2021 09:44:40 GMT')
# ('Content-Type', 'text/html; charset=UTF-8')
# ('Transfer-Encoding', 'chunked')
# ('Connection', 'close')
# ('Set-Cookie', 'PM_CK_loc=a952fbbfa71b60ee97401635f0db1206e4d78e0ef882b9b4b92b50dc72182bbd; Expires=Wed, 31 Mar 2021 09:44:40 GMT; Path=/; HttpOnly')
# ('Cache-Control', 'no-cache, no-store, must-revalidate')
# ('Pragma', 'no-cache')
# ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"')
# ('X-Frame-Options', 'DENY')
# ('X-XSS-Protection', '1; mode=block')
# ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains')
# ('Referrer-Policy', 'unsafe-url')

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res)
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
#print(res.read())
print(res.read().decode('utf-8')) # 한글이 포함된 사이트 읽어올 때
# Out:
# <http.client.HTTPResponse object at 0x0000021D85494760>
# [ header 정보 ]----------
# ('Date', 'Tue, 30 Mar 2021 09:44:45 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# </head>
# <body>
# <h1>블럭스타일 태그</h1>
# <div style="background-color:yellow">테스트입니다1</div>
# <div>테스트입니다2</div>
# <div>테스트입니다3</div>
# <hr>
# <h1>인라인스타일 태그</h1>
# <span style="background-color:yellow">테스트입니다1</span>
# <span>테스트입니다2</span>
# <span>테스트입니다3</span>
# </body>
# </html>

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.daum.net/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.aladin.co.kr/home/welcome.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

# %%
from urllib.parse import urlparse
from urllib.parse import urlencode
print("[ URL 문자열 정보 추출 1 ]")
url1 = urlparse('https://movie.daum.net/moviedb/main?movieId=93252')
print("타입정보 : ",type(url1))
print("도메인정보 : ",url1.netloc) 
print("패스정보 : ",url1.path)
print("쿼리정보 : ",url1.query) 
print("스킴정보 : ",url1.scheme)
print("포트정보 : ",url1.port)
print("프래그먼트정보 : ",url1.fragment)
print("URL 문자열정보 : ",url1.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url1)
print("\n[ URL 문자열 정보 추출 2 ]")
url2 = urlparse('https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object')
print("도메인정보 : ",url2.netloc) 
print("패스정보 : ", url2.path)  
print("쿼리정보 : ",url2.query)
print("스킴정보 : ",url2.scheme)
print("포트정보 : ",url2.port)
print("프래그먼트정보 : ",url2.fragment)
print("URL 문자열정보 : ",url2.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url2)

print("\n[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8')) # f.read 응답 바디를 통째로 읽어라? GET방식

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii') # POST 방식
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))

# %%
import requests

# head, body 같이
r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r)) # 어떤 객체를 리턴하는 지 확인
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8' # head만~ head태그 아님
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8' # post방식 지원안해서 php파일 따로,, 요청파라미터 필수, 전달되는 네임밸류쌍이 외부노출x 길이제한x, 추가데이터
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.head('http://unico2013.dothome.co.kr/crawling/exam.html')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))
# Out:
# ï»¿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : ì´ë¦ê³¼ ëì´ë¥¼ ì ë¬í´ ì£¼ì¸ì!!</h1>   </body>
# </html>
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\r\n</html>'
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content))
print(type(i))
i.save("output/test.jpg")

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify())
print(bs)

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[ string 속성 ]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[ text 속성 ]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[ contents 속성 ]")
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
#print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
# 인코딩 안줌 >> utf-8이 아니여서
html = req.text # 텍스트 추출
soup = BeautifulSoup(html, 'html.parser') # 추출한 텍스트를 BeautifulSoup에 전달
titles = soup.select('.movie') # 클래스 속성
points = soup.select('td.title > div > em') # 태그객체 고르기
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6] 
    #content=re.sub("신고", '', content) gsub와 비슷
    content=re.sub("[\n\t]", '', content) #개행, 탭 삭제
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 고질라 VS. 콩
# 평점 : 10
# 리뷰글 : 용아맥가서 봣는데 진짜 영상미지림 ㅋㅋㅋㅋ 킬링타임용
# -----------------------------------------
# 영화 제목 : 극장판 귀멸의 칼날: 무한열차편
# 평점 : 10
# 리뷰글 : 원피스 제외하고 넷플릭스통해 살면서 처음으로 보게된 일본애니... 너무 재밌게봐서 영화관에 뒷내용 보러 왔다가... 진짜 입을 다물수가 없었음... 슬프기도 엄청 슬프고... 오타쿠 같아 보일까봐 걱정했는데... 생각보다 사람들 꽉 차서 다행이었음ㅋㅋㅋ
# -----------------------------------------
# 영화 제목 : 미나리
# 평점 : 6
# 리뷰글 : 졸리고 지루했어요기대를 너무많이했나봐요ㅠㅠ
# -----------------------------------------
# 영화 제목 : 미션 파서블
# 평점 : 7
# 리뷰글 : 딱 두번 진짜 웃김 나머지 쏘쏘~킬링타임용~네이버 알바 대박 10점주고 ㅋㅋㅋ네이버 정보가 점점 믿을수 없어짐~;;; 예전에는 그래도 어느정도 믿을만 했는데;;;어떤 의도아닌 의도가 들어간 듯한 느낌 ㅎ;;;
# -----------------------------------------
# 영화 제목 : 더 박스
# 평점 : 10
# 리뷰글 :
# -----------------------------------------
# 영화 제목 : 작은 아씨들
# 평점 : 10
# 리뷰글 : 현재와 과거를 교차하면서 보여주는것도 좋았고, 배우들의 연기도 좋았어요. 따뜻한 영화입니다. 결말도 좋았어요!
# -----------------------------------------
# 영화 제목 : 거북이는 의외로 빨리 헤엄친다
# 평점 : 10
# 리뷰글 : 나 이 영화 진짜 좋아. 정말 사랑하는 영화
# -----------------------------------------
# 영화 제목 : 최면
# 평점 : 2
# 리뷰글 : 화면에 계속 이상한 잔상뜨던데 그거 노린건가요?
# -----------------------------------------
# 영화 제목 : 해피 피트
# 평점 : 2
# 리뷰글 : 어린이용 애니메이션 뮤지컬
# -----------------------------------------
# 영화 제목 : 혐오스런 마츠코의 일생
# 평점 : 10
# 리뷰글 : 살다가 문득 마츠코가 떠오르는 날이 있다. 사무치게 아프고 아련한데 절대 잊고 싶지 않은 영화.
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31): #문자열 결합할 때 str(n)로 줘야함
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        #content=re.sub("신고", '', content)
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 10,라야와 마지막 드래곤,너무재밌었어용
# 10,미나리,신선하고 색다른 영화입니다 배우 한분 한분 연기력도 대단했고 가장 보고싶었던 스티븐 연 배우님을 볼수 있어서 좋았어요 힐링되고 감동적인 영화였어요! 잘봤습니다!
# 10,자산어보,
# 10,해리 포터와 마법사의 돌,어릴적 나를 설레게 해주었던 판타지 세상..! 그립다.
# 10,고질라 VS. 콩,지렸다리 지렸다리!!!!
# 10,장고:분노의 추적자,크리스토퍼 왈츠의 연기는 언제나 맛깔납니다
# 10,해리 포터와 아즈카반의 죄수,전 이게 시리즈 중에 베스트
# 2,승리호,보는내내  몰입안됨   240 억들여서  만든영화라니  엘리시움  흉내낸건아니겠지
# 4,고질라 VS. 콩,노잼 ㅇㅈ응 ㅇㅈ 끝입니다
# 10,해리 포터와 비밀의 방,해리포터가 해리포터했다
# -----------------------------------------------------
# 10,레미: 집 없는 아이,아이 미모에 푹 빠져 보게된 영화 잔잔하게 집중도도 좋고, 따뜻함이 느껴지는 좋은 영화네요
# 10,해리 포터와 마법사의 돌,말이 필요없죠 해리포터인데
# 6,고질라 VS. 콩,영화로는 별로지만 '쇼'로 보기엔 즐거운....
# 10,인터스텔라,
# 8,자산어보,영화관에서 근래봤던 한국영화중 가장 볼만한듯용
# 10,플립,90분이 전혀 지루하지 않고 집중하면서 보게 됐다. 표면적으로 봤을 때 서로간의 감정을 말하지 않으면 오해를 하게 되고, 그 오해를 풀기 위해 행동을 하며 성장하고 노력하는 모습을 보여준 남주의 캐릭터가 인상깊었으나 여주의 독보적인 캐릭터와 그녀의 가족들의 모습이 부럽기도 하며 부러웠다. 나 또한 반성하게 되는 생각을 갖게 되는 참 아름다운 영화다.
# 10,중경삼림,이 이야기 말하는 사랑에는 두가지가 필요하다. 인연과 기다림
# 8,고질라 VS. 콩,굿굿 시원한 액션씬 재밌는 영화
# 8,존 윅,외롭지 않고 슬퍼할 수 있도록 사랑하는 사람의 마지막 배려이자 선물을... 차도 차지만 이건 선 넘었지...
# 10,자산어보,역시 이준익 감독님이네요
# -----------------------------------------------------
# 1,고질라 VS. 콩,평점이 너무 거품 같아서 깎는다. 스토리들 한 개 한 개가 다 너무 뻔했고 저연령 공략해서 그랬나 참 유치했다. 액션성은 좋았다
# 9,고질라 VS. 콩,어른 어린이 다좋아할만한 영화
# 10,82년생 김지영,개봉할 때 영화관에서 봤다가 갑자기 평점 낮은거 보고 엥? 싶어서 별점 주러 옴.. 책하고는 스토리가 많이 다른 것 같지만 그래도 음.. 그냥 자연스럽게 우리 일상의 여성의 모습을 잘 표현했다고 생각해요.  아니 근데 성별/나이별 관람객 평점 다른거 ㅋ ㅋㅋ  웃기네요
# 10,자산어보,간만에 영화봤는데 감동
# 10,자산어보,그 당시 백성들의 삶을 보고 눈물 흘렸습니다.
# 10,조제, 호랑이 그리고 물고기들,기대를 많이 하고 갔는데 기대 이상 연출도 좋았고, 감정선이 와닿은 점 정말 좋음 인생작에 들어갈 수준
# 9,고질라 VS. 콩,그냥 그랬어요! 킬링 타임용으로 좋았어요
# 10,자산어보,흑백영화라 처음엔 어색했지만 볼수록 몰입감이 상승연출력좋고 간만에 여운있는 영화 관람.자산어보추천!
# -----------------------------------------------------
# 10,후 아 유,그때의 감성을 느낄 수 있는영화왜 이제야 본거지
# 10,자산어보,너무 감동적이였어요ㅠㅠ 예고편도 보고 흑백영화는 처음이라서 궁금해서봤는데ㅠㅠ재밌었어요
# 2,고백,페미에 의해 페미가 만든 페미영화
# 2,고질라 VS. 콩,감독 누구냐? 유치하기 짝이 없다 건물에 하나 같이 형광등 달아놨냐? 콩 쇠사슬이 묶여서 조용히 끌려배로 이동되는 장면도 웃기고 그 쌔던 콩이 가슴 살짝 끍혔다고 OO려고 하고 수화하는 꼬맹이는 초능력자냐? 수화로 콩하고 얘길하네? 반대편 땅구덩이로 가는 설정도 개판이구 아무튼 전체적으로 똥망영화네 ㅡㅡ;;;;
# 10,자산어보,잊고살앟던   잔잔한감동잏네요 저  왕의남자   5번보았어요
# 6,고질라 VS. 콩,전투 액션만큼은 트랜스포머급 최고임 근데 좀 유치함 본래 고질라 시리즈 스토리보다 더 구리게 나온듯 그리고 배경음악 생각보다 되게 좋아서 다시 찾아서 듣는중 콩은 괴수의 면모가 잘 안나와서 전편 콩이 나은듯
# 10,조제, 호랑이 그리고 물고기들,
# 10,고질라 VS. 콩,메카 고질라 나온다고 해서 기대안했는데 역대급..
# 7,흥부: 글로 세상을 바꾼 자,메세지는 분명 있는데 좀 부족합니다. 정해인 대사없는거 마음에 안듬.
# 10,킬러파티 (양수리 살인사건),재밌음  황당해서  웃긴.. 또 웃으면서 뭔가 당혹스러움ㅋㅋㅋㅋ음악, 뮤지컬 즐긴다면 꼭 추천합니다
# -----------------------------------------------------
# 1,당신의 사월,의도는 알겠는데, 이젠 안 먹힌다. 이건 떠나간 아이들을 위하는 일도 아니다.
# 2,워킹걸,
# 10,플립,사랑을 넘어 깊은 울림을 주는 영화
# 10,고질라 VS. 콩,시국이 시국인만큼 관객수가 안타깝네~올해 본 영화중에 최고~콩의 아련한 눈빛과 콩과 고질라가 싸우는 장면이 압권입니다.둘의 우정도?콩 고질라 우정 포에버^^
# 8,잭 스나이더의 저스티스 리그,오호 이정도로? 나쁘지안앗???
# 10,베어,너무 감동적이였어요ㅠㅠ
# 6,더 시크릿,킬링 타임으로는 볼만 합니다.
# 10,어벤져스: 엔드게임,
# 10,더 박스,정말 힐링되는 영화이예요. 노래들 진짜 잘 불러셨어여~
# 10,람보,40년이  지난 영화 이지만 정말 명작이다.요즘 영화라해도 믿겠다... 참전한 특전사의 사회 부적응과 냉대에 대한 이야기...
# -----------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
titleList = bs.select('p.goods_name.goods_icon > a > strong')
linklList = bs.select('p.goods_name.goods_icon > a')

for titleDom in titleList:
    title.append(titleDom.string)
for linkDom in linklList:
    link.append(linkDom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
with open('output/booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '혼자 공부하는 파이썬', '혼자 공부하는 머신러닝+딥러닝', '두근두근 파이썬', '파이썬 for Beginner', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', '밑바닥부터 시작하는 딥러닝 ', '파이썬을 이용한 비트코인 자동매매', '파이썬 증권 데이터 분석 ', '핸즈온 머신러닝', '파이썬 머신러닝 완벽 가이드', '파이썬 알고리즘 인터뷰', '실전 시계열 분석', '혼자 공부하는 첫 프로그래밍 with 파이썬 ', 'Do it! 파이썬 생활 프로그래밍', 'Do it! 점프 투 파이썬 + Do it! 파이썬 생활 프로그래밍', '시간순삭 파이썬', '파이썬으로 배우는 컴퓨팅 사고', '밑바닥부터 시작하는 딥러닝 2', '어서와 파이썬은 처음이지!']
# -- 도서 링크 URL --
# ['/Product/Goods/74419916?OzSrank=1', '/Product/Goods/74269975?OzSrank=2', '/Product/Goods/96024871?OzSrank=3', '/Product/Goods/35279965?OzSrank=4', '/Product/Goods/83849188?OzSrank=5', '/Product/Goods/91433923?OzSrank=6', '/Product/Goods/34970929?OzSrank=7', '/Product/Goods/98135876?OzSrank=8', '/Product/Goods/90578506?OzSrank=9', '/Product/Goods/89959711?OzSrank=10', '/Product/Goods/87044746?OzSrank=11', '/Product/Goods/91084402?OzSrank=12', '/Product/Goods/98576347?OzSrank=13', '/Product/Goods/90617738?OzSrank=14', '/Product/Goods/91437485?OzSrank=15', '/Product/Goods/91446225?OzSrank=16', '/Product/Goods/92087970?OzSrank=17', '/Product/Goods/70749127?OzSrank=18', '/Product/Goods/72173703?OzSrank=19', '/Product/Goods/30575427?OzSrank=20']

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename = "C:/Temp/forecast.xml"
req.urlretrieve(url, savename)

xml = open(savename, "r", encoding="utf-8").read()
soup = BeautifulSoup(xml, 'html.parser')

info = {}
for location in soup.find_all("location"):
    loc = location.find('city').string
    min_w = location.find_all('tmn')
    max_w = location.find_all('tmx')
    weather = [a.string+"~"+b.string for a, b in zip(min_w, max_w)]

    if not (loc in info):
        info[loc] = []
    for data in weather:
        info[loc].append(data)
print(info)

with open('C:/Temp/forecast.txt', "wt", encoding="utf-8") as f:
    for loc in sorted(info.keys()):
        f.write(str(loc)+'\n')
        for name in info[loc]:
            f.write('\t'+str(name)+'\n')

# %%
import json
import urllib.request

#User-Agent를 조작하는 경우 
hdr = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '+ 
        'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.80 Safari/537.36'}

req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php', headers = hdr)
#req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php')
data = urllib.request.urlopen(req).read()
print(data)
#page = data.decode('utf-8', 'ignore')
res_content = json.loads(data)

print(res_content["result"])
